# %% [markdown]
# <a href="https://colab.research.google.com/github/dgjkim0858/python-master/blob/main/01%EC%9E%A5_%EC%86%8C%EC%8A%A4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 31쪽

# %%
print('반갑습니다. 파이썬입니다.')

# %% [markdown]
# 34쪽

# %%
print('반갑습니다.')
print('파이썬입니다.')

# %% [markdown]
# 35쪽

# %%
print(3*7)

# %% [markdown]
# **[플러스] 문자열 출력**

# %%
print('홍길동님, 안녕하세요!')

# %% [markdown]
# **[플러스] 연산 결과 출력**

# %%
print(5*100)
